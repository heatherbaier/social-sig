# %%
import numpy as np
import torch
import math
import pytorchvis

# %%
class SocialSig(torch.nn.Module):
    '''
    Class to create the social signature image
    '''
    def __init__(self, X, W):
        super(SocialSig, self).__init__()
        self.W = W
        self.outDim = [10,10]
        self.inDim = math.ceil(math.sqrt(len(X)))
        self.X = X
        

    def forward(self):
        xTemp = torch.stack([self.X, self.W])
        X = torch.sort(xTemp, dim=1, descending=False)
        buildImage = torch.reshape(X[0][0],(1, 1, self.inDim, self.inDim))
        return torch.nn.functional.interpolate(buildImage, size=([self.outDim[0], self.outDim[1]]), mode='bilinear')

# %%
class SocialSigNet(torch.nn.Module):
    def __init__(self, X):
        """
        In the constructor we instantiate four parameters and assign them as
        member parameters.
        """
        super().__init__()
        self.W = torch.nn.Parameter(torch.tensor(np.arange(0,len(X)), dtype = torch.float32, requires_grad=True))
        self.SocialSig = SocialSig(X,self.W)                
        self.maxPool = torch.nn.MaxPool2d(kernel_size=(10,10))  #10,10 is static here.  Will need to be dynamic based on user dim settings.

    def forward(self, X):
        print("    W at beginning: ", self.W.data)
        out = self.SocialSig()
        out = self.maxPool(out)
        
        return out

# %%
# Create random tensors to hold input and outputs.
X = torch.tensor([-1.6848, -0.6, -93.2, -182.2], requires_grad = True)
y = torch.tensor([0.0359], requires_grad = True)

# Construct our model by instantiating the class defined above
model = SocialSigNet(X=X)
#print(dir(model))
print(list(model.parameters()))
# Out:
# [Parameter containing:
# tensor([0., 1., 2., 3.], requires_grad=True)]

# %%
# from torchviz import make_dot

# make_dot(model(X), params=dict(list(model.named_parameters()))).render("backPropViz", format="png")

# %%
# Setting the LR to something dumb just to test that things are indeed working
lr = 10
criterion = torch.nn.MSELoss(reduction='none')
optimizer = torch.optim.SGD(model.parameters(), lr = lr)


def update_function(param, grad, loss, learning_rate):
    return param - learning_rate * grad


for t in range(100):
    print("EPOCH: ", t)
    y_pred = model(X)
    print("    Predicted Y:    ", y_pred)
    loss = criterion(y_pred, y)
    print("    Loss:           ", loss)

    # Zero gradients, perform a backward pass, and update the weights.
    optimizer.zero_grad()
    grad = torch.autograd.grad(outputs=loss, inputs=X, retain_graph = True)
    print("    Gradient:       ", grad[0])
    loss.backward()
    optimizer.step()
    # https://discuss.pytorch.org/t/updatation-of-parameters-without-using-optimizer-step/34244/4
    with torch.no_grad():
        for p in model.parameters():
            print("    In with:        ", p.data)
            new_val = update_function(p, grad[0], loss, lr)
            p.copy_(new_val)
    
    print("\n")

def inspectModel(model):
    print("Model.parameters")
    print(model.parameters)
    print("SSParam")
    print(list(model.SocialSig.parameters()))
    print("is_leaf")
    print(list(model.SocialSig.parameters())[0].is_leaf)
    print("gradfn")
    print(list(model.SocialSig.parameters())[0].grad_fn)
    print("Grad")
    print(list(model.SocialSig.parameters())[0].grad)
# Out:
# .0000, 598.7459,   2.0000,   3.0000])
#     Predicted Y:     tensor([[[[-0.6000]]]], grad_fn=<MaxPool2DWithIndicesBackward>)
#     Loss:            tensor([[[[0.4044]]]], grad_fn=<MseLossBackward>)
#     Gradient:        tensor([ 0.0000, -1.2718,  0.0000,  0.0000])
#     In with:         tensor([  0.0000, 598.7459,   2.0000,   3.0000])
#
#
# EPOCH:  48
#     W at beginning:  tensor([  0.0000, 611.4639,   2.0000,   3.0000])
#     Predicted Y:     tensor([[[[-0.6000]]]], grad_fn=<MaxPool2DWithIndicesBackward>)
#     Loss:            tensor([[[[0.4044]]]], grad_fn=<MseLossBackward>)
#     Gradient:        tensor([ 0.0000, -1.2718,  0.0000,  0.0000])
#     In with:         tensor([  0.0000, 611.4639,   2.0000,   3.0000])
#
#
# EPOCH:  49
#     W at beginning:  tensor([  0.0000, 624.1819,   2.0000,   3.0000])
#     Predicted Y:     tensor([[[[-0.6000]]]], grad_fn=<MaxPool2DWithIndicesBackward>)
#     Loss:            tensor([[[[0.4044]]]], grad_fn=<MseLossBackward>)
#     Gradient:        tensor([ 0.0000, -1.2718,  0.0000,  0.0000])
#     In with:         tensor([  0.0000, 624.1819,   2.0000,   3.0000])
#
#
# EPOCH:  50
#     W at beginning:  tensor([  0.0000, 636.9000,   2.0000,   3.0000])
#     Predicted Y:     tensor([[[[-0.6000]]]], grad_fn=<MaxPool2DWithIndicesBackward>)
#     Loss:            tensor([[[[0.4044]]]], grad_fn=<MseLossBackward>)
#     Gradient:        tensor([ 0.0000, -1.2718,  0.0000,  0.0000])
#     In with:         tensor([  0.0000, 636.9000,   2.0000,   3.0000])
#
#
# EPOCH:  51
#     W at beginning:  tensor([  0.0000, 649.6180,   2.0000,   3.0000])
#     Predicted Y:     tensor([[[[-0.6000]]]], grad_fn=<MaxPool2DWithIndicesBackward>)
#     Loss:            tensor([[[[0.4044]]]], grad_fn=<MseLossBackward>)
#     Gradient:        tensor([ 0.0000, -1.2718,  0.0000,  0.0000])
#     In with:         tensor([  0.0000, 649.6180,   2.0000,   3.0000])
#
#
# EPOCH:  52
#     W at beginning:  tensor([  0.0000, 662.3360,   2.0000,   3.0000])
#     Predicted Y:     tensor([[[[-0.6000]]]], grad_fn=<MaxPool2DWithIndicesBackward>)
#     Loss:            tensor([[[[0.4044]]]], grad_fn=<MseLossBackward>)
#     Gradient:        tensor([ 0.0000, -1.2718,  0.0000,  0.0000])
#     In with:         tensor([  0.0000, 662.3360,   2.0000,   3.0000])
#
#
# EPOCH:  53
#     W at beginning:  tensor([  0.0000, 675.0540,   2.0000,   3.0000])
#     Predicted Y:     tensor([[[[-0.6000]]]], grad_fn=<MaxPool2DWithIndicesBackward>)
#     Loss:            tensor([[[[0.4044]]]], grad_fn=<MseLossBackward>)
#     Gradient:        tensor([ 0.0000, -1.2718,  0.0000,  0.0000])
#     In with:         tensor([  0.0000, 675.0540,   2.0000,   3.0000])
#
#
# EPOCH:  54
#     W at beginning:  tensor([  0.0000, 687.7720,   2.0000,   3.0000])
#     Predicted Y:     tensor([[[[-0.6000]]]], grad_fn=<MaxPool2DWithIndicesBackward>)
#     Loss:            tensor([[[[0.4044]]]], grad_fn=<MseLossBackward>)
#     Gradient:        tensor([ 0.0000, -1.2718,  0.0000,  0.0000])
#     In with:         tensor([  0.0000, 687.7720,   2.0000,   3.0000])
#
#
# EPOCH:  55
#     W at beginning:  tensor([  0.0000, 700.4901,   2.0000,   3.0000])
#     Predicted Y:     tensor([[[[-0.6000]]]], grad_fn=<MaxPool2DWithIndicesBackward>)
#     Loss:            tensor([[[[0.4044]]]], grad_fn=<MseLossBackward>)
#     Gradient:        tensor([ 0.0000, -1.2718,  0.0000,  0.0000])
#     In with:         tensor([  0.0000, 700.4901,   2.0000,   3.0000])
#
#
# EPOCH:  56
#     W at beginning:  tensor([  0.0000, 713.2081,   2.0000,   3.0000])
#     Predicted Y:     tensor([[[[-0.6000]]]], grad_fn=<MaxPool2DWithIndicesBackward>)
#     Loss:            tensor([[[[0.4044]]]], grad_fn=<MseLossBackward>)
#     Gradient:        tensor([ 0.0000, -1.2718,  0.0000,  0.0000])
#     In with:         tensor([  0.0000, 713.2081,   2.0000,   3.0000])
#
#
# EPOCH:  57
#     W at beginning:  tensor([  0.0000, 725.9261,   2.0000,   3.0000])
#     Predicted Y:     tensor([[[[-0.6000]]]], grad_fn=<MaxPool2DWithIndicesBackward>)
#     Loss:            tensor([[[[0.4044]]]], grad_fn=<MseLossBackward>)
#     Gradient:        tensor([ 0.0000, -1.2718,  0.0000,  0.0000])
#     In with:         tensor([  0.0000, 725.9261,   2.0000,   3.0000])
#
#
# EPOCH:  58
#     W at beginning:  tensor([  0.0000, 738.6441,   2.0000,   3.0000])
#     Predicted Y:     tensor([[[[-0.6000]]]], grad_fn=<MaxPool2DWithIndicesBackward>)
#     Loss:            tensor([[[[0.4044]]]], grad_fn=<MseLossBackward>)
#     Gradient:        tensor([ 0.0000, -1.2718,  0.0000,  0.0000])
#     In with:         tensor([  0.0000, 738.6441,   2.0000,   3.0000])
#
#
# EPOCH:  59
#     W at beginning:  tensor([  0.0000, 751.3621,   2.0000,   3.0000])
#     Predicted Y:     tensor([[[[-0.6000]]]], grad_fn=<MaxPool2DWithIndicesBackward>)
#     Loss:            tensor([[[[0.4044]]]], grad_fn=<MseLossBackward>)
#     Gradient:        tensor([ 0.0000, -1.2718,  0.0000,  0.0000])
#     In with:         tensor([  0.0000, 751.3621,   2.0000,   3.0000])
#
#
# EPOCH:  60
#     W at beginning:  tensor([  0.0000, 764.0801,   2.0000,   3.0000])
#     Predicted Y:     tensor([[[[-0.6000]]]], grad_fn=<MaxPool2DWithIndicesBackward>)
#     Loss:            tensor([[[[0.4044]]]], grad_fn=<MseLossBackward>)
#     Gradient:        tensor([ 0.0000, -1.2718,  0.0000,  0.0000])
#     In with:         tensor([  0.0000, 764.0801,   2.0000,   3.0000])
#
#
# EPOCH:  61
#     W at beginning:  tensor([  0.0000, 776.7982,   2.0000,   3.0000])
#     Predicted Y:     tensor([[[[-0.6000]]]], grad_fn=<MaxPool2DWithIndicesBackward>)
#     Loss:            tensor([[[[0.4044]]]], grad_fn=<MseLossBackward>)
#     Gradient:        tensor([ 0.0000, -1.2718,  0.0000,  0.0000])
#     In with:         tensor([  0.0000, 776.7982,   2.0000,   3.0000])
#
#
# EPOCH:  62
#     W at beginning:  tensor([  0.0000, 789.5162,   2.0000,   3.0000])
#     Predicted Y:     tensor([[[[-0.6000]]]], grad_fn=<MaxPool2DWithIndicesBackward>)
#     Loss:            tensor([[[[0.4044]]]], grad_fn=<MseLossBackward>)
#     Gradient:        tensor([ 0.0000, -1.2718,  0.0000,  0.0000])
#     In with:         tensor([  0.0000, 789.5162,   2.0000,   3.0000])
#
#
# EPOCH:  63
#     W at beginning:  tensor([  0.0000, 802.2342,   2.0000,   3.0000])
#     Predicted Y:     tensor([[[[-0.6000]]]], grad_fn=<MaxPool2DWithIndicesBackward>)
#     Loss:            tensor([[[[0.4044]]]], grad_fn=<MseLossBackward>)
#     Gradient:        tensor([ 0.0000, -1.2718,  0.0000,  0.0000])
#     In with:         tensor([  0.0000, 802.2342,   2.0000,   3.0000])
#
#
# EPOCH:  64
#     W at beginning:  tensor([  0.0000, 814.9522,   2.0000,   3.0000])
#     Predicted Y:     tensor([[[[-0.6000]]]], grad_fn=<MaxPool2DWithIndicesBackward>)
#     Loss:            tensor([[[[0.4044]]]], grad_fn=<MseLossBackward>)
#     Gradient:        tensor([ 0.0000, -1.2718,  0.0000,  0.0000])
#     In with:         tensor([  0.0000, 814.9522,   2.0000,   3.0000])
#
#
# EPOCH:  65
#     W at beginning:  tensor([  0.0000, 827.6702,   2.0000,   3.0000])
#     Predicted Y:     tensor([[[[-0.6000]]]], grad_fn=<MaxPool2DWithIndicesBackward>)
#     Loss:            tensor([[[[0.4044]]]], grad_fn=<MseLossBackward>)
#     Gradient:        tensor([ 0.0000, -1.2718,  0.0000,  0.0000])
#     In with:         tensor([  0.0000, 827.6702,   2.0000,   3.0000])
#
#
# EPOCH:  66
#     W at beginning:  tensor([  0.0000, 840.3882,   2.0000,   3.0000])
#     Predicted Y:     tensor([[[[-0.6000]]]], grad_fn=<MaxPool2DWithIndicesBackward>)
#     Loss:            tensor([[[[0.4044]]]], grad_fn=<MseLossBackward>)
#     Gradient:        tensor([ 0.0000, -1.2718,  0.0000,  0.0000])
#     In with:         tensor([  0.0000, 840.3882,   2.0000,   3.0000])
#
#
# EPOCH:  67
#     W at beginning:  tensor([  0.0000, 853.1063,   2.0000,   3.0000])
#     Predicted Y:     tensor([[[[-0.6000]]]], grad_fn=<MaxPool2DWithIndicesBackward>)
#     Loss:            tensor([[[[0.4044]]]], grad_fn=<MseLossBackward>)
#     Gradient:        tensor([ 0.0000, -1.2718,  0.0000,  0.0000])
#     In with:         tensor([  0.0000, 853.1063,   2.0000,   3.0000])
#
#
# EPOCH:  68
#     W at beginning:  tensor([  0.0000, 865.8243,   2.0000,   3.0000])
#     Predicted Y:     tensor([[[[-0.6000]]]], grad_fn=<MaxPool2DWithIndicesBackward>)
#     Loss:            tensor([[[[0.4044]]]], grad_fn=<MseLossBackward>)
#     Gradient:        tensor([ 0.0000, -1.2718,  0.0000,  0.0000])
#     In with:         tensor([  0.0000, 865.8243,   2.0000,   3.0000])
#
#
# EPOCH:  69
#     W at beginning:  tensor([  0.0000, 878.5423,   2.0000,   3.0000])
#     Predicted Y:     tensor([[[[-0.6000]]]], grad_fn=<MaxPool2DWithIndicesBackward>)
#     Loss:            tensor([[[[0.4044]]]], grad_fn=<MseLossBackward>)
#     Gradient:        tensor([ 0.0000, -1.2718,  0.0000,  0.0000])
#     In with:         tensor([  0.0000, 878.5423,   2.0000,   3.0000])
#
#
# EPOCH:  70
#     W at beginning:  tensor([  0.0000, 891.2603,   2.0000,   3.0000])
#     Predicted Y:     tensor([[[[-0.6000]]]], grad_fn=<MaxPool2DWithIndicesBackward>)
#     Loss:            tensor([[[[0.4044]]]], grad_fn=<MseLossBackward>)
#     Gradient:        tensor([ 0.0000, -1.2718,  0.0000,  0.0000])
#     In with:         tensor([  0.0000, 891.2603,   2.0000,   3.0000])
#
#
# EPOCH:  71
#     W at beginning:  tensor([  0.0000, 903.9783,   2.0000,   3.0000])
#     Predicted Y:     tensor([[[[-0.6000]]]], grad_fn=<MaxPool2DWithIndicesBackward>)
#     Loss:            tensor([[[[0.4044]]]], grad_fn=<MseLossBackward>)
#     Gradient:        tensor([ 0.0000, -1.2718,  0.0000,  0.0000])
#     In with:         tensor([  0.0000, 903.9783,   2.0000,   3.0000])
#
#
# EPOCH:  72
#     W at beginning:  tensor([  0.0000, 916.6964,   2.0000,   3.0000])
#     Predicted Y:     tensor([[[[-0.6000]]]], grad_fn=<MaxPool2DWithIndicesBackward>)
#     Loss:            tensor([[[[0.4044]]]], grad_fn=<MseLossBackward>)
#     Gradient:        tensor([ 0.0000, -1.2718,  0.0000,  0.0000])
#     In with:         tensor([  0.0000, 916.6964,   2.0000,   3.0000])
#
#
# EPOCH:  73
#     W at beginning:  tensor([  0.0000, 929.4144,   2.0000,   3.0000])
#     Predicted Y:     tensor([[[[-0.6000]]]], grad_fn=<MaxPool2DWithIndicesBackward>)
#     Loss:            tensor([[[[0.4044]]]], grad_fn=<MseLossBackward>)
#     Gradient:        tensor([ 0.0000, -1.2718,  0.0000,  0.0000])
#     In with:         tensor([  0.0000, 929.4144,   2.0000,   3.0000])
#
#
# EPOCH:  74
#     W at beginning:  tensor([  0.0000, 942.1324,   2.0000,   3.0000])
#     Predicted Y:     tensor([[[[-0.6000]]]], grad_fn=<MaxPool2DWithIndicesBackward>)
#     Loss:            tensor([[[[0.4044]]]], grad_fn=<MseLossBackward>)
#     Gradient:        tensor([ 0.0000, -1.2718,  0.0000,  0.0000])
#     In with:         tensor([  0.0000, 942.1324,   2.0000,   3.0000])
#
#
# EPOCH:  75
#     W at beginning:  tensor([  0.0000, 954.8504,   2.0000,   3.0000])
#     Predicted Y:     tensor([[[[-0.6000]]]], grad_fn=<MaxPool2DWithIndicesBackward>)
#     Loss:            tensor([[[[0.4044]]]], grad_fn=<MseLossBackward>)
#     Gradient:        tensor([ 0.0000, -1.2718,  0.0000,  0.0000])
#     In with:         tensor([  0.0000, 954.8504,   2.0000,   3.0000])
#
#
# EPOCH:  76
#     W at beginning:  tensor([  0.0000, 967.5684,   2.0000,   3.0000])
#     Predicted Y:     tensor([[[[-0.6000]]]], grad_fn=<MaxPool2DWithIndicesBackward>)
#     Loss:            tensor([[[[0.4044]]]], grad_fn=<MseLossBackward>)
#     Gradient:        tensor([ 0.0000, -1.2718,  0.0000,  0.0000])
#     In with:         tensor([  0.0000, 967.5684,   2.0000,   3.0000])
#
#
# EPOCH:  77
#     W at beginning:  tensor([  0.0000, 980.2864,   2.0000,   3.0000])
#     Predicted Y:     tensor([[[[-0.6000]]]], grad_fn=<MaxPool2DWithIndicesBackward>)
#     Loss:            tensor([[[[0.4044]]]], grad_fn=<MseLossBackward>)
#     Gradient:        tensor([ 0.0000, -1.2718,  0.0000,  0.0000])
#     In with:         tensor([  0.0000, 980.2864,   2.0000,   3.0000])
#
#
# EPOCH:  78
#     W at beginning:  tensor([  0.0000, 993.0045,   2.0000,   3.0000])
#     Predicted Y:     tensor([[[[-0.6000]]]], grad_fn=<MaxPool2DWithIndicesBackward>)
#     Loss:            tensor([[[[0.4044]]]], grad_fn=<MseLossBackward>)
#     Gradient:        tensor([ 0.0000, -1.2718,  0.0000,  0.0000])
#     In with:         tensor([  0.0000, 993.0045,   2.0000,   3.0000])
#
#
# EPOCH:  79
#     W at beginning:  tensor([   0.0000, 1005.7225,    2.0000,    3.0000])
#     Predicted Y:     tensor([[[[-0.6000]]]], grad_fn=<MaxPool2DWithIndicesBackward>)
#     Loss:            tensor([[[[0.4044]]]], grad_fn=<MseLossBackward>)
#     Gradient:        tensor([ 0.0000, -1.2718,  0.0000,  0.0000])
#     In with:         tensor([   0.0000, 1005.7225,    2.0000,    3.0000])
#
#
# EPOCH:  80
#     W at beginning:  tensor([   0.0000, 1018.4405,    2.0000,    3.0000])
#     Predicted Y:     tensor([[[[-0.6000]]]], grad_fn=<MaxPool2DWithIndicesBackward>)
#     Loss:            tensor([[[[0.4044]]]], grad_fn=<MseLossBackward>)
#     Gradient:        tensor([ 0.0000, -1.2718,  0.0000,  0.0000])
#     In with:         tensor([   0.0000, 1018.4405,    2.0000,    3.0000])
#
#
# EPOCH:  81
#     W at beginning:  tensor([   0.0000, 1031.1584,    2.0000,    3.0000])
#     Predicted Y:     tensor([[[[-0.6000]]]], grad_fn=<MaxPool2DWithIndicesBackward>)
#     Loss:            tensor([[[[0.4044]]]], grad_fn=<MseLossBackward>)
#     Gradient:        tensor([ 0.0000, -1.2718,  0.0000,  0.0000])
#     In with:         tensor([   0.0000, 1031.1584,    2.0000,    3.0000])
#
#
# EPOCH:  82
#     W at beginning:  tensor([   0.0000, 1043.8765,    2.0000,    3.0000])
#     Predicted Y:     tensor([[[[-0.6000]]]], grad_fn=<MaxPool2DWithIndicesBackward>)
#     Loss:            tensor([[[[0.4044]]]], grad_fn=<MseLossBackward>)
#     Gradient:        tensor([ 0.0000, -1.2718,  0.0000,  0.0000])
#     In with:         tensor([   0.0000, 1043.8765,    2.0000,    3.0000])
#
#
# EPOCH:  83
#     W at beginning:  tensor([   0.0000, 1056.5945,    2.0000,    3.0000])
#     Predicted Y:     tensor([[[[-0.6000]]]], grad_fn=<MaxPool2DWithIndicesBackward>)
#     Loss:            tensor([[[[0.4044]]]], grad_fn=<MseLossBackward>)
#     Gradient:        tensor([ 0.0000, -1.2718,  0.0000,  0.0000])
#     In with:         tensor([   0.0000, 1056.5945,    2.0000,    3.0000])
#
#
# EPOCH:  84
#     W at beginning:  tensor([   0.0000, 1069.3125,    2.0000,    3.0000])
#     Predicted Y:     tensor([[[[-0.6000]]]], grad_fn=<MaxPool2DWithIndicesBackward>)
#     Loss:            tensor([[[[0.4044]]]], grad_fn=<MseLossBackward>)
#     Gradient:        tensor([ 0.0000, -1.2718,  0.0000,  0.0000])
#     In with:         tensor([   0.0000, 1069.3125,    2.0000,    3.0000])
#
#
# EPOCH:  85
#     W at beginning:  tensor([   0.0000, 1082.0305,    2.0000,    3.0000])
#     Predicted Y:     tensor([[[[-0.6000]]]], grad_fn=<MaxPool2DWithIndicesBackward>)
#     Loss:            tensor([[[[0.4044]]]], grad_fn=<MseLossBackward>)
#     Gradient:        tensor([ 0.0000, -1.2718,  0.0000,  0.0000])
#     In with:         tensor([   0.0000, 1082.0305,    2.0000,    3.0000])
#
#
# EPOCH:  86
#     W at beginning:  tensor([   0.0000, 1094.7485,    2.0000,    3.0000])
#     Predicted Y:     tensor([[[[-0.6000]]]], grad_fn=<MaxPool2DWithIndicesBackward>)
#     Loss:            tensor([[[[0.4044]]]], grad_fn=<MseLossBackward>)
#     Gradient:        tensor([ 0.0000, -1.2718,  0.0000,  0.0000])
#     In with:         tensor([   0.0000, 1094.7485,    2.0000,    3.0000])
#
#
# EPOCH:  87
#     W at beginning:  tensor([   0.0000, 1107.4666,    2.0000,    3.0000])
#     Predicted Y:     tensor([[[[-0.6000]]]], grad_fn=<MaxPool2DWithIndicesBackward>)
#     Loss:            tensor([[[[0.4044]]]], grad_fn=<MseLossBackward>)
#     Gradient:        tensor([ 0.0000, -1.2718,  0.0000,  0.0000])
#     In with:         tensor([   0.0000, 1107.4666,    2.0000,    3.0000])
#
#
# EPOCH:  88
#     W at beginning:  tensor([   0.0000, 1120.1846,    2.0000,    3.0000])
#     Predicted Y:     tensor([[[[-0.6000]]]], grad_fn=<MaxPool2DWithIndicesBackward>)
#     Loss:            tensor([[[[0.4044]]]], grad_fn=<MseLossBackward>)
#     Gradient:        tensor([ 0.0000, -1.2718,  0.0000,  0.0000])
#     In with:         tensor([   0.0000, 1120.1846,    2.0000,    3.0000])
#
#
# EPOCH:  89
#     W at beginning:  tensor([   0.0000, 1132.9026,    2.0000,    3.0000])
#     Predicted Y:     tensor([[[[-0.6000]]]], grad_fn=<MaxPool2DWithIndicesBackward>)
#     Loss:            tensor([[[[0.4044]]]], grad_fn=<MseLossBackward>)
#     Gradient:        tensor([ 0.0000, -1.2718,  0.0000,  0.0000])
#     In with:         tensor([   0.0000, 1132.9026,    2.0000,    3.0000])
#
#
# EPOCH:  90
#     W at beginning:  tensor([   0.0000, 1145.6206,    2.0000,    3.0000])
#     Predicted Y:     tensor([[[[-0.6000]]]], grad_fn=<MaxPool2DWithIndicesBackward>)
#     Loss:            tensor([[[[0.4044]]]], grad_fn=<MseLossBackward>)
#     Gradient:        tensor([ 0.0000, -1.2718,  0.0000,  0.0000])
#     In with:         tensor([   0.0000, 1145.6206,    2.0000,    3.0000])
#
#
# EPOCH:  91
#     W at beginning:  tensor([   0.0000, 1158.3386,    2.0000,    3.0000])
#     Predicted Y:     tensor([[[[-0.6000]]]], grad_fn=<MaxPool2DWithIndicesBackward>)
#     Loss:            tensor([[[[0.4044]]]], grad_fn=<MseLossBackward>)
#     Gradient:        tensor([ 0.0000, -1.2718,  0.0000,  0.0000])
#     In with:         tensor([   0.0000, 1158.3386,    2.0000,    3.0000])
#
#
# EPOCH:  92
#     W at beginning:  tensor([   0.0000, 1171.0566,    2.0000,    3.0000])
#     Predicted Y:     tensor([[[[-0.6000]]]], grad_fn=<MaxPool2DWithIndicesBackward>)
#     Loss:            tensor([[[[0.4044]]]], grad_fn=<MseLossBackward>)
#     Gradient:        tensor([ 0.0000, -1.2718,  0.0000,  0.0000])
#     In with:         tensor([   0.0000, 1171.0566,    2.0000,    3.0000])
#
#
# EPOCH:  93
#     W at beginning:  tensor([   0.0000, 1183.7747,    2.0000,    3.0000])
#     Predicted Y:     tensor([[[[-0.6000]]]], grad_fn=<MaxPool2DWithIndicesBackward>)
#     Loss:            tensor([[[[0.4044]]]], grad_fn=<MseLossBackward>)
#     Gradient:        tensor([ 0.0000, -1.2718,  0.0000,  0.0000])
#     In with:         tensor([   0.0000, 1183.7747,    2.0000,    3.0000])
#
#
# EPOCH:  94
#     W at beginning:  tensor([   0.0000, 1196.4927,    2.0000,    3.0000])
#     Predicted Y:     tensor([[[[-0.6000]]]], grad_fn=<MaxPool2DWithIndicesBackward>)
#     Loss:            tensor([[[[0.4044]]]], grad_fn=<MseLossBackward>)
#     Gradient:        tensor([ 0.0000, -1.2718,  0.0000,  0.0000])
#     In with:         tensor([   0.0000, 1196.4927,    2.0000,    3.0000])
#
#
# EPOCH:  95
#     W at beginning:  tensor([   0.0000, 1209.2107,    2.0000,    3.0000])
#     Predicted Y:     tensor([[[[-0.6000]]]], grad_fn=<MaxPool2DWithIndicesBackward>)
#     Loss:            tensor([[[[0.4044]]]], grad_fn=<MseLossBackward>)
#     Gradient:        tensor([ 0.0000, -1.2718,  0.0000,  0.0000])
#     In with:         tensor([   0.0000, 1209.2107,    2.0000,    3.0000])
#
#
# EPOCH:  96
#     W at beginning:  tensor([   0.0000, 1221.9287,    2.0000,    3.0000])
#     Predicted Y:     tensor([[[[-0.6000]]]], grad_fn=<MaxPool2DWithIndicesBackward>)
#     Loss:            tensor([[[[0.4044]]]], grad_fn=<MseLossBackward>)
#     Gradient:        tensor([ 0.0000, -1.2718,  0.0000,  0.0000])
#     In with:         tensor([   0.0000, 1221.9287,    2.0000,    3.0000])
#
#
# EPOCH:  97
#     W at beginning:  tensor([   0.0000, 1234.6467,    2.0000,    3.0000])
#     Predicted Y:     tensor([[[[-0.6000]]]], grad_fn=<MaxPool2DWithIndicesBackward>)
#     Loss:            tensor([[[[0.4044]]]], grad_fn=<MseLossBackward>)
#     Gradient:        tensor([ 0.0000, -1.2718,  0.0000,  0.0000])
#     In with:         tensor([   0.0000, 1234.6467,    2.0000,    3.0000])
#
#
# EPOCH:  98
#     W at beginning:  tensor([   0.0000, 1247.3647,    2.0000,    3.0000])
#     Predicted Y:     tensor([[[[-0.6000]]]], grad_fn=<MaxPool2DWithIndicesBackward>)
#     Loss:            tensor([[[[0.4044]]]], grad_fn=<MseLossBackward>)
#     Gradient:        tensor([ 0.0000, -1.2718,  0.0000,  0.0000])
#     In with:         tensor([   0.0000, 1247.3647,    2.0000,    3.0000])
#
#
# EPOCH:  99
#     W at beginning:  tensor([   0.0000, 1260.0828,    2.0000,    3.0000])
#     Predicted Y:     tensor([[[[-0.6000]]]], grad_fn=<MaxPool2DWithIndicesBackward>)
#     Loss:            tensor([[[[0.4044]]]], grad_fn=<MseLossBackward>)
#     Gradient:        tensor([ 0.0000, -1.2718,  0.0000,  0.0000])
#     In with:         tensor([   0.0000, 1260.0828,    2.0000,    3.0000])
